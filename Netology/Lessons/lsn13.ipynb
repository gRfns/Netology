# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
URL = 'https://habr.com/ru/all/'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36'
}

# %%
def get_html(url, params=''):
    r = requests.get(url, headers=HEADERS, params=params)
    return r

# %%
def get_content(link):
    soup = BeautifulSoup(html.text, 'html.parser')
    posts = soup.find_all('article', class_='post')
    post_list = pd.DataFrame()
    KEYWORDS = ['python', 'парсинг']
    for inf in posts:
        date_post = inf.find('span', class_= 'post__time').text
        title = inf.find('a', class_='post__title_link').text  
        post_prev = inf.find('div', class_='post__text').get_text(strip=True)
        for word in KEYWORDS:
            if word in title or word in post_prev:
                row = {'date': date_post, 'title': title, 'post_prev': post_prev}
                post_list = pd.concat([post_list, pd.DataFrame([row])])
    return post_list.to_csv('parser_habr.csv', sep=';', encoding='utf-8')

# %%
def parser():
    html = get_html(URL)
    if html.status_code == 200:
            get_content(html)
    else:
        print('Error')

# %%
parser()
df = pd.read_csv('parser_habr.csv', sep=';')
df.head()
# Out:
#    Unnamed: 0             date  \
# 0           0  сегодня в 12:20
#
#                                                title  \
# 0  Организация сбора и парсинга логов при помощи ...
#
#                                            post_prev
# 0  В комментариях к моемутуториалу, рассказывающе...

# %% [markdown]
# #### Задание 2

# %%
URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36',

    'Vaar-Header-App-Product': 'hackcheck-web-avast',
    'Vaar-Version': '0',
    'Vaar-Header-App-Product-Name': 'hackcheck-web-avast',
    'Vaar-Header-App-Build-Version': '1.0.0',

    'Accept': 'application/json, text/plain, */*',
    'Content-Type': 'application/json;charset=UTF-8',
    'Host': 'identityprotection.avast.com',
    'Origin': 'https://www.avast.com',
    'Referer': 'https://www.avast.com/'
}
PAYLOAD = {
    'emailAddresses': ['xxx@ya.ru','yyy@y.com']
}
r = requests.post(URL, headers=HEADERS, json=PAYLOAD)

# %%
d = r.json()['data']
pd.DataFrame(d)
# Out:
#                                                     hurb.com  \
# xxx@ya.ru  [{'breachId': 17847, 'usernameBreached': True,...
# yyy@y.com                                                NaN
#
#                                              wowprogress.com  \
# xxx@ya.ru  [{'breachId': 17093, 'usernameBreached': True,...
# yyy@y.com                                                NaN
#
#                                                    adobe.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 3, 'usernameBreached': True, 'pa...
#
#                                               ir.netease.com  \
# xxx@ya.ru  [{'breachId': 88, 'usernameBreached': True, 'p...
# yyy@y.com                                                NaN
#
#                                           cityofvillains.com  \
# xxx@ya.ru  [{'breachId': 17345, 'usernameBreached': True,...
# yyy@y.com                                                NaN
#
#                                                azcentral.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 17110, 'usernameBreached': True,...
#
#                                                 linkedin.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 2, 'usernameBreached': True, 'pa...
#
#                                                  dropbox.com  \
# xxx@ya.ru  [{'breachId': 41, 'usernameBreached': True, 'p...
# yyy@y.com  [{'breachId': 41, 'usernameBreached': True, 'p...
#
#                                                  wishbone.io  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 17670, 'usernameBreached': True,...
#
#                                                    youku.com  ...  \
# xxx@ya.ru                                                NaN  ...
# yyy@y.com  [{'breachId': 3669, 'usernameBreached': True, ...  ...
#
#                                                 rayli.com.cn  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 3587, 'usernameBreached': True, ...
#
#                                                    canva.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 16768, 'usernameBreached': True,...
#
#                                               globalreach.eu  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 3520, 'usernameBreached': True, ...
#
#                                                       qip.ru  \
# xxx@ya.ru  [{'breachId': 60, 'usernameBreached': True, 'p...
# yyy@y.com                                                NaN
#
#                                                       vk.com  \
# xxx@ya.ru  [{'breachId': 12, 'usernameBreached': True, 'p...
# yyy@y.com                                                NaN
#
#                                         forums.vkmonline.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 37177, 'usernameBreached': True,...
#
#                                                   wanadoo.fr  \
# xxx@ya.ru  [{'breachId': 3560, 'usernameBreached': True, ...
# yyy@y.com                                                NaN
#
#                                                   netlog.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 13662, 'usernameBreached': True,...
#
#                                                    imesh.com  \
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 15, 'usernameBreached': True, 'p...
#
#                                                    zynga.com
# xxx@ya.ru                                                NaN
# yyy@y.com  [{'breachId': 17009, 'usernameBreached': True,...
#
# [2 rows x 22 columns]
